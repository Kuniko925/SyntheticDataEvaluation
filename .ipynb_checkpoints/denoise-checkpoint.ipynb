# %%
# %load_ext autoreload
# %autoreload 2

import wave
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
root = "../../dataset/CIFAKE/cifake1/test/REAL/frog/"

# %%
image_path = f"{root}0000 (7).jpg"
# %run wave.py "$image_path" --outdir wave_out
# Out:
# DONE
# dominant k: 1
# wave score : 4.980633716315084

# %%
for i in range(10):
    image_path = f"{root}000{i} (7).jpg"
    # %run wave.py "$image_path" --outdir wave_out
# Out:
# DONE
# dominant k: 1
# wave score : 4.980633716315084
# DONE
# dominant k: 2
# wave score : 5.370561467959533
# DONE
# dominant k: 2
# wave score : 6.135051823179195
# DONE
# dominant k: 2
# wave score : 6.378256619608163
# DONE
# dominant k: 1
# wave score : 5.701475505667828
# DONE
# dominant k: 1
# wave score : 6.60913030603759
# DONE
# dominant k: 2
# wave score : 6.155547313720946
# DONE
# dominant k: 2
# wave score : 6.031117953122832
# DONE
# dominant k: 2
# wave score : 6.135051711972948
# DONE
# dominant k: 1
# wave score : 5.807383954756399

# %%
for i in range(10):
    image_path = f"{root}000{i} (7).jpg"
    # %run wave.py "$image_path" --outdir wave_out
# Out:
# DONE
# dominant k: 4
# wave score : 10.51379495485327
# DONE
# dominant k: 3
# wave score : 12.442558416209664
# DONE
# dominant k: 4
# wave score : 14.161183803868042
# DONE
# dominant k: 3
# wave score : 11.769641203522832
# DONE
# dominant k: 3
# wave score : 12.580857299358106
# DONE
# dominant k: 3
# wave score : 12.528804289357593
# DONE
# dominant k: 4
# wave score : 11.993143307952066
# DONE
# dominant k: 3
# wave score : 12.638616757073738
# DONE
# dominant k: 3
# wave score : 9.576333011219083
# DONE
# dominant k: 3
# wave score : 11.489801649352081

# %%
root = "../../dataset/CIFAKE/cifake1/test/FAKE/frog/"

# %%
for i in range(10):
    image_path = f"{root}{i} (7).jpg"
    # %run wave.py "$image_path" --outdir wave_out
# Out:
# DONE
# dominant k: 2
# wave score : 10.708684892698598
# DONE
# dominant k: 3
# wave score : 12.701278829901606
# DONE
# dominant k: 2
# wave score : 14.708821476391773
# DONE
# dominant k: 2
# wave score : 13.006000905758624
# DONE
# dominant k: 3
# wave score : 12.107896286295876
# DONE
# dominant k: 2
# wave score : 12.825772454196771
# DONE
# dominant k: 2
# wave score : 11.535544492038907
# DONE
# dominant k: 2
# wave score : 12.892627110288782
# DONE
# dominant k: 2
# wave score : 14.266179774916333
# DONE
# dominant k: 2
# wave score : 12.885675311433308

# %%
for i in range(10):
    image_path = f"{root}{i} (7).jpg"
    # %run wave.py "$image_path" --outdir wave_out
# Out:
# DONE
# dominant k: 3
# wave score : 9.380654710507423
# DONE
# dominant k: 3
# wave score : 13.762247121057523
# DONE
# dominant k: 3
# wave score : 12.556238267757923
# DONE
# dominant k: 3
# wave score : 10.595849517502375
# DONE
# dominant k: 4
# wave score : 12.399983503209665
# DONE
# dominant k: 3
# wave score : 10.866962319250867
# DONE
# dominant k: 4
# wave score : 13.52646501158361
# DONE
# dominant k: 3
# wave score : 10.502299939460856
# DONE
# dominant k: 3
# wave score : 11.136503712941426
# DONE
# dominant k: 3
# wave score : 12.772710359990175
